# %%
import math
import requests
import datetime
from statistics import mean
import time
import sys

YEAR = 2020
WEEK = 13
POST_WEEK = 0
LI_RATIO = .1
L_SHARE = LI_RATIO
I_SHARE = 1 - LI_RATIO
TRANSFER_RATIO = 1
MARGIN_LOG = 7

# %%
#prev = requests.get('https://api.collegefootballdata.com/games?year=' + str(YEAR - 1) + '&seasonType=regular')
#prev_post = requests.get('https://api.collegefootballdata.com/games?year=' + str(YEAR - 1) + '&seasonType=postseason')
reg = requests.get('https://api.collegefootballdata.com/games?year=' + str(YEAR) + '&seasonType=regular')
post = requests.get('https://api.collegefootballdata.com/games?year=' + str(YEAR) + '&seasonType=postseason')
records = {}
games = reg.json() + post.json() #+ prev.json() + prev_post.json()

# %%
for game in games:
        
    away_team = game['away_team']
    home_team = game['home_team']
    
    # With this dataset, no conference listed means they are an FCS team. 
    # I treat all FCS teams as the same, likely crappy team. 
    if not game['away_conference']:
        away_team = 'FCS Team'
    if not game['home_conference']:
        home_team = 'FCS Team'   
    
    if away_team not in records:
        records[away_team] = []
    if home_team not in records:
        records[home_team] = []
    
    if ((game['season_type'] != 'postseason'and game['week'] > WEEK) 
        or (game['season_type'] == 'postseason' and game['week'] > POST_WEEK)):
        continue
    
    # For invalid/unplayed games
    if game['away_points'] == None:
        continue
        
    margin = game['away_points'] - game['home_points']
    
    # Going to overtime counts as a one point win
    if len(game['away_line_scores']) > 4:
        margin = margin / abs(margin)
    records[away_team].append((home_team, margin))
    records[home_team].append((away_team, -margin))

# %%
AP_Ranks = {}
for team in records:
    AP_Ranks[team] = '-'
reg = requests.get('https://api.collegefootballdata.com/rankings?year=' + str(YEAR) 
                   + '&week=' + str(WEEK + POST_WEEK + 1)
                   + '&seasonType=regular')
for e in reg.json()[0]['polls']:
    if e['poll'] == 'AP Top 25':
        for row in e['ranks']:
            AP_Ranks[row['school']] = str(row['rank'])

# %%
records['Northwestern']
# Out:
# [('Maryland', 40),
#  ('Iowa', 1),
#  ('Nebraska', 8),
#  ('Purdue', 7),
#  ('Wisconsin', 10),
#  ('Michigan State', -9)]

# %%
# Get last weeks result!
last_week_table = {}
with open('Output - ' + str(YEAR) + '-' + str(WEEK + POST_WEEK - 1) + '.md', 'r') as last_week:
    rows = last_week.read().split('\n')
    header = []
    for row in rows:
        if '|' in row:
            cells = row.split('|')
            if header == []:
                header = cells
                team_loc = header.index('Team')
            else:
                team = '('.join(cells[team_loc].split('(')[0:-1]) # Get the team name without record, but with (OH)
                last_week_table[team] = {}
                for i, cell in enumerate(cells):
                    if cell == '':
                        continue
                    last_week_table[team][header[i]] = cell

# %%
last_week_table
# Out:
# {'': {'Rank': '-',
#   'Score': '-',
#   'Team': '-',
#   'AP Rank': '-',
#   'Past Rank': '-',
#   'Score Change': '-',
#   'Breakdown': '-'},
#  'BYU': {'Rank': '1',
#   'Score': '1384',
#   'Team': 'BYU(9-0)',
#   'AP Rank': '8',
#   'Past Rank': '1',
#   'Score Change': '-63',
#   'Breakdown': 'See Link'},
#  'Cincinnati': {'Rank': '2',
#   'Score': '1322',
#   'Team': 'Cincinnati(8-0)',
#   'AP Rank': '7',
#   'Past Rank': '2',
#   'Score Change': '-31',
#   'Breakdown': 'See Link'},
#  'Alabama': {'Rank': '3',
#   'Score': '1277',
#   'Team': 'Alabama(7-0)',
#   'AP Rank': '1',
#   'Past Rank': '4',
#   'Score Change': '+205',
#   'Breakdown': 'See Link'},
#  'Coastal Carolina': {'Rank': '4',
#   'Score': '1092',
#   'Team': 'Coastal Carolina(8-0)',
#   'AP Rank': '16',
#   'Past Rank': '3',
#   'Score Change': '-158',
#   'Breakdown': 'See Link'},
#  'Clemson': {'Rank': '5',
#   'Score': '1068',
#   'Team': 'Clemson(7-1)',
#   'AP Rank': '4',
#   'Past Rank': '6',
#   'Score Change': '+96',
#   'Breakdown': 'See Link'},
#  'Notre Dame': {'Rank': '6',
#   'Score': '1016',
#   'Team': 'Notre Dame(8-0)',
#   'AP Rank': '2',
#   'Past Rank': '8',
#   'Score Change': '+161',
#   'Breakdown': 'See Link'},
#  'Marshall': {'Rank': '7',
#   'Score': '878',
#   'Team': 'Marshall(7-0)',
#   'AP Rank': '17',
#   'Past Rank': '7',
#   'Score Change': '-13',
#   'Breakdown': 'See Link'},
#  'Miami': {'Rank': '8',
#   'Score': '876',
#   'Team': 'Miami(7-1)',
#   'AP Rank': '10',
#   'Past Rank': '9',
#   'Score Change': '+73',
#   'Breakdown': 'See Link'},
#  'Louisiana': {'Rank': '9',
#   'Score': '853',
#   'Team': 'Louisiana(7-1)',
#   'AP Rank': '23',
#   'Past Rank': '5',
#   'Score Change': '-125',
#   'Breakdown': 'See Link'},
#  'Northwestern': {'Rank': '10',
#   'Score': '723',
#   'Team': 'Northwestern(5-0)',
#   'AP Rank': '11',
#   'Past Rank': '12',
#   'Score Change': '+135',
#   'Breakdown': 'See Link'},
#  'Iowa State': {'Rank': '11',
#   'Score': '653',
#   'Team': 'Iowa State(6-2)',
#   'AP Rank': '15',
#   'Past Rank': '18',
#   'Score Change': '+214',
#   'Breakdown': 'See Link'},
#  'Boise State': {'Rank': '12',
#   'Score': '561',
#   'Team': 'Boise State(4-1)',
#   'AP Rank': '-',
#   'Past Rank': '19',
#   'Score Change': '+137',
#   'Breakdown': 'See Link'},
#  'Oklahoma': {'Rank': '13',
#   'Score': '561',
#   'Team': 'Oklahoma(6-2)',
#   'AP Rank': '14',
#   'Past Rank': '35',
#   'Score Change': '+340',
#   'Breakdown': 'See Link'},
#  'Florida': {'Rank': '14',
#   'Score': '555',
#   'Team': 'Florida(6-1)',
#   'AP Rank': '6',
#   'Past Rank': '15',
#   'Score Change': '+52',
#   'Breakdown': 'See Link'},
#  'Oklahoma State': {'Rank': '15',
#   'Score': '537',
#   'Team': 'Oklahoma State(5-2)',
#   'AP Rank': '21',
#   'Past Rank': '10',
#   'Score Change': '-146',
#   'Breakdown': 'See Link'},
#  'San José State': {'Rank': '16',
#   'Score': '537',
#   'Team': 'San José State(4-0)',
#   'AP Rank': '-',
#   'Past Rank': '13',
#   'Score Change': '-47',
#   'Breakdown': 'See Link'},
#  'Texas A&M': {'Rank': '17',
#   'Score': '515',
#   'Team': 'Texas A&M(5-1)',
#   'AP Rank': '5',
#   'Past Rank': '16',
#   'Score Change': '+30',
#   'Breakdown': 'See Link'},
#  'Ohio State': {'Rank': '18',
#   'Score': '489',
#   'Team': 'Ohio State(4-0)',
#   'AP Rank': '3',
#   'Past Rank': '27',
#   'Score Change': '+180',
#   'Breakdown': 'See Link'},
#  'Georgia': {'Rank': '19',
#   'Score': '460',
#   'Team': 'Georgia(5-2)',
#   'AP Rank': '13',
#   'Past Rank': '22',
#   'Score Change': '+74',
#   'Breakdown': 'See Link'},
#  'Tulsa': {'Rank': '20',
#   'Score': '453',
#   'Team': 'Tulsa(5-1)',
#   'AP Rank': '24',
#   'Past Rank': '11',
#   'Score Change': '-151',
#   'Breakdown': 'See Link'},
#  'Nevada': {'Rank': '21',
#   'Score': '428',
#   'Team': 'Nevada(5-0)',
#   'AP Rank': '-',
#   'Past Rank': '30',
#   'Score Change': '+148',
#   'Breakdown': 'See Link'},
#  'Western Michigan': {'Rank': '22',
#   'Score': '388',
#   'Team': 'Western Michigan(3-0)',
#   'AP Rank': '-',
#   'Past Rank': '36',
#   'Score Change': '+172',
#   'Breakdown': 'See Link'},
#  'SMU': {'Rank': '23',
#   'Score': '386',
#   'Team': 'SMU(7-2)',
#   'AP Rank': '-',
#   'Past Rank': '14',
#   'Score Change': '-157',
#   'Breakdown': 'See Link'},
#  'Oregon': {'Rank': '24',
#   'Score': '386',
#   'Team': 'Oregon(3-0)',
#   'AP Rank': '9',
#   'Past Rank': '32',
#   'Score Change': '+122',
#   'Breakdown': 'See Link'},
#  'Buffalo': {'Rank': '25',
#   'Score': '371',
#   'Team': 'Buffalo(3-0)',
#   'AP Rank': '-',
#   'Past Rank': '28',
#   'Score Change': '+66',
#   'Breakdown': 'See Link'},
#  'UCF': {'Rank': '26',
#   'Score': '351',
#   'Team': 'UCF(5-3)',
#   'AP Rank': '-',
#   'Past Rank': '17',
#   'Score Change': '-133',
#   'Breakdown': 'See Link'},
#  'Florida Atlantic': {'Rank': '27',
#   'Score': '326',
#   'Team': 'Florida Atlantic(5-1)',
#   'AP Rank': '-',
#   'Past Rank': '41',
#   'Score Change': '+141',
#   'Breakdown': 'See Link'},
#  'North Carolina': {'Rank': '28',
#   'Score': '323',
#   'Team': 'North Carolina(6-2)',
#   'AP Rank': '25',
#   'Past Rank': '29',
#   'Score Change': '+38',
#   'Breakdown': 'See Link'},
#  'Indiana': {'Rank': '29',
#   'Score': '323',
#   'Team': 'Indiana(4-1)',
#   'AP Rank': '12',
#   'Past Rank': '25',
#   'Score Change': '+9',
#   'Breakdown': 'See Link'},
#  'Appalachian State': {'Rank': '30',
#   'Score': '294',
#   'Team': 'Appalachian State(6-2)',
#   'AP Rank': '-',
#   'Past Rank': '20',
#   'Score Change': '-123',
#   'Breakdown': 'See Link'},
#  'Texas': {'Rank': '31',
#   'Score': '290',
#   'Team': 'Texas(5-2)',
#   'AP Rank': '20',
#   'Past Rank': '38',
#   'Score Change': '+80',
#   'Breakdown': 'See Link'},
#  'USC': {'Rank': '32',
#   'Score': '275',
#   'Team': 'USC(3-0)',
#   'AP Rank': '19',
#   'Past Rank': '45',
#   'Score Change': '+132',
#   'Breakdown': 'See Link'},
#  'NC State': {'Rank': '33',
#   'Score': '255',
#   'Team': 'NC State(6-3)',
#   'AP Rank': '-',
#   'Past Rank': '40',
#   'Score Change': '+68',
#   'Breakdown': 'See Link'},
#  'Liberty': {'Rank': '34',
#   'Score': '254',
#   'Team': 'Liberty(8-1)',
#   'AP Rank': '-',
#   'Past Rank': '23',
#   'Score Change': '-105',
#   'Breakdown': 'See Link'},
#  'Wisconsin': {'Rank': '35',
#   'Score': '246',
#   'Team': 'Wisconsin(2-1)',
#   'AP Rank': '18',
#   'Past Rank': '37',
#   'Score Change': '+31',
#   'Breakdown': 'See Link'},
#  'Memphis': {'Rank': '36',
#   'Score': '241',
#   'Team': 'Memphis(5-2)',
#   'AP Rank': '-',
#   'Past Rank': '24',
#   'Score Change': '-115',
#   'Breakdown': 'See Link'},
#  'Wake Forest': {'Rank': '37',
#   'Score': '241',
#   'Team': 'Wake Forest(4-3)',
#   'AP Rank': '-',
#   'Past Rank': '34',
#   'Score Change': '+17',
#   'Breakdown': 'See Link'},
#  'Kent State': {'Rank': '38',
#   'Score': '238',
#   'Team': 'Kent State(3-0)',
#   'AP Rank': '-',
#   'Past Rank': '44',
#   'Score Change': '+74',
#   'Breakdown': 'See Link'},
#  'Houston': {'Rank': '39',
#   'Score': '224',
#   'Team': 'Houston(3-3)',
#   'AP Rank': '-',
#   'Past Rank': '26',
#   'Score Change': '-88',
#   'Breakdown': 'See Link'},
#  'San Diego State': {'Rank': '40',
#   'Score': '222',
#   'Team': 'San Diego State(3-2)',
#   'AP Rank': '-',
#   'Past Rank': '31',
#   'Score Change': '-53',
#   'Breakdown': 'See Link'},
#  'Washington': {'Rank': '41',
#   'Score': '213',
#   'Team': 'Washington(2-0)',
#   'AP Rank': '-',
#   'Past Rank': '52',
#   'Score Change': '+142',
#   'Breakdown': 'See Link'},
#  'Colorado': {'Rank': '42',
#   'Score': '193',
#   'Team': 'Colorado(2-0)',
#   'AP Rank': '-',
#   'Past Rank': '43',
#   'Score Change': '+27',
#   'Breakdown': 'See Link'},
#  'Pittsburgh': {'Rank': '43',
#   'Score': '183',
#   'Team': 'Pittsburgh(5-4)',
#   'AP Rank': '-',
#   'Past Rank': '74',
#   'Score Change': '+217',
#   'Breakdown': 'See Link'},
#  'Air Force': {'Rank': '44',
#   'Score': '153',
#   'Team': 'Air Force(2-2)',
#   'AP Rank': '-',
#   'Past Rank': '47',
#   'Score Change': '+58',
#   'Breakdown': 'See Link'},
#  'West Virginia': {'Rank': '45',
#   'Score': '149',
#   'Team': 'West Virginia(5-3)',
#   'AP Rank': '-',
#   'Past Rank': '53',
#   'Score Change': '+82',
#   'Breakdown': 'See Link'},
#  'Toledo': {'Rank': '46',
#   'Score': '138',
#   'Team': 'Toledo(2-1)',
#   'AP Rank': '-',
#   'Past Rank': '57',
#   'Score Change': '+106',
#   'Breakdown': 'See Link'},
#  'Central Michigan': {'Rank': '47',
#   'Score': '135',
#   'Team': 'Central Michigan(2-1)',
#   'AP Rank': '-',
#   'Past Rank': '33',
#   'Score Change': '-93',
#   'Breakdown': 'See Link'},
#  'Virginia': {'Rank': '48',
#   'Score': '131',
#   'Team': 'Virginia(4-4)',
#   'AP Rank': '-',
#   'Past Rank': '51',
#   'Score Change': '+59',
#   'Breakdown': 'See Link'},
#  'Virginia Tech': {'Rank': '49',
#   'Score': '128',
#   'Team': 'Virginia Tech(4-5)',
#   'AP Rank': '-',
#   'Past Rank': '39',
#   'Score Change': '-68',
#   'Breakdown': 'See Link'},
#  'Georgia Southern': {'Rank': '50',
#   'Score': '119',
#   'Team': 'Georgia Southern(6-3)',
#   'AP Rank': '-',
#   'Past Rank': '21',
#   'Score Change': '-268',
#   'Breakdown': 'See Link'},
#  'Kansas State': {'Rank': '51',
#   'Score': '118',
#   'Team': 'Kansas State(4-4)',
#   'AP Rank': '-',
#   'Past Rank': '49',
#   'Score Change': '+38',
#   'Breakdown': 'See Link'},
#  'TCU': {'Rank': '52',
#   'Score': '102',
#   'Team': 'TCU(3-4)',
#   'AP Rank': '-',
#   'Past Rank': '72',
#   'Score Change': '+119',
#   'Breakdown': 'See Link'},
#  'Iowa': {'Rank': '53',
#   'Score': '73',
#   'Team': 'Iowa(3-2)',
#   'AP Rank': '-',
#   'Past Rank': '46',
#   'Score Change': '-38',
#   'Breakdown': 'See Link'},
#  'Army': {'Rank': '54',
#   'Score': '69',
#   'Team': 'Army(7-2)',
#   'AP Rank': '-',
#   'Past Rank': '63',
#   'Score Change': '+49',
#   'Breakdown': 'See Link'},
#  'Fresno State': {'Rank': '55',
#   'Score': '60',
#   'Team': 'Fresno State(3-1)',
#   'AP Rank': '-',
#   'Past Rank': '55',
#   'Score Change': '+1',
#   'Breakdown': 'See Link'},
#  'Miami (OH)': {'Rank': '56',
#   'Score': '58',
#   'Team': 'Miami (OH)(1-1)',
#   'AP Rank': '-',
#   'Past Rank': '58',
#   'Score Change': '+29',
#   'Breakdown': 'See Link'},
#  'Maryland': {'Rank': '57',
#   'Score': '57',
#   'Team': 'Maryland(2-1)',
#   'AP Rank': '-',
#   'Past Rank': '56',
#   'Score Change': '+10',
#   'Breakdown': 'See Link'},
#  'Boston College': {'Rank': '58',
#   'Score': '55',
#   'Team': 'Boston College(5-4)',
#   'AP Rank': '-',
#   'Past Rank': '69',
#   'Score Change': '+67',
#   'Breakdown': 'See Link'},
#  'Purdue': {'Rank': '59',
#   'Score': '54',
#   'Team': 'Purdue(2-2)',
#   'AP Rank': '-',
#   'Past Rank': '42',
#   'Score Change': '-123',
#   'Breakdown': 'See Link'},
#  'UAB': {'Rank': '60',
#   'Score': '54',
#   'Team': 'UAB(4-3)',
#   'AP Rank': '-',
#   'Past Rank': '50',
#   'Score Change': '-23',
#   'Breakdown': 'See Link'},
#  'Washington State': {'Rank': '61',
#   'Score': '47',
#   'Team': 'Washington State(1-1)',
#   'AP Rank': '-',
#   'Past Rank': '66',
#   'Score Change': '+46',
#   'Breakdown': 'See Link'},
#  'Tulane': {'Rank': '62',
#   'Score': '25',
#   'Team': 'Tulane(5-5)',
#   'AP Rank': '-',
#   'Past Rank': '48',
#   'Score Change': '-62',
#   'Breakdown': 'See Link'},
#  'Ball State': {'Rank': '63',
#   'Score': '21',
#   'Team': 'Ball State(2-1)',
#   'AP Rank': '-',
#   'Past Rank': '73',
#   'Score Change': '+54',
#   'Breakdown': 'See Link'},
#  'Louisiana Tech': {'Rank': '64',
#   'Score': '8',
#   'Team': 'Louisiana Tech(4-3)',
#   'AP Rank': '-',
#   'Past Rank': '64',
#   'Score Change': '0',
#   'Breakdown': 'See Link'},
#  'Ohio': {'Rank': '65',
#   'Score': '-4',
#   'Team': 'Ohio(1-1)',
#   'AP Rank': '-',
#   'Past Rank': '59',
#   'Score Change': '-31',
#   'Breakdown': 'See Link'},
#  'Texas Tech': {'Rank': '66',
#   'Score': '-8',
#   'Team': 'Texas Tech(3-5)',
#   'AP Rank': '-',
#   'Past Rank': '83',
#   'Score Change': '+113',
#   'Breakdown': 'See Link'},
#  'Auburn': {'Rank': '67',
#   'Score': '-17',
#   'Team': 'Auburn(5-2)',
#   'AP Rank': '22',
#   'Past Rank': '76',
#   'Score Change': '+49',
#   'Breakdown': 'See Link'},
#  'Colorado State': {'Rank': '68',
#   'Score': '-19',
#   'Team': 'Colorado State(1-2)',
#   'AP Rank': '-',
#   'Past Rank': '71',
#   'Score Change': '-5',
#   'Breakdown': 'See Link'},
#  'Arizona State': {'Rank': '69',
#   'Score': '-34',
#   'Team': 'Arizona State(0-1)',
#   'AP Rank': '-',
#   'Past Rank': '75',
#   'Score Change': '+11',
#   'Breakdown': 'See Link'},
#  "Hawai'i": {'Rank': '70',
#   'Score': '-36',
#   'Team': "Hawai'i(2-3)",
#   'AP Rank': '-',
#   'Past Rank': '70',
#   'Score Change': '-22',
#   'Breakdown': 'See Link'},
#  'Wyoming': {'Rank': '71',
#   'Score': '-38',
#   'Team': 'Wyoming(1-2)',
#   'AP Rank': '-',
#   'Past Rank': '65',
#   'Score Change': '-44',
#   'Breakdown': 'See Link'},
#  'UCLA': {'Rank': '72',
#   'Score': '-39',
#   'Team': 'UCLA(1-2)',
#   'AP Rank': '-',
#   'Past Rank': '80',
#   'Score Change': '+44',
#   'Breakdown': 'See Link'},
#  'Navy': {'Rank': '73',
#   'Score': '-43',
#   'Team': 'Navy(3-4)',
#   'AP Rank': '-',
#   'Past Rank': '60',
#   'Score Change': '-66',
#   'Breakdown': 'See Link'},
#  'UT San Antonio': {'Rank': '74',
#   'Score': '-75',
#   'Team': 'UT San Antonio(6-4)',
#   'AP Rank': '-',
#   'Past Rank': '82',
#   'Score Change': '+45',
#   'Breakdown': 'See Link'},
#  'Utah': {'Rank': '75',
#   'Score': '-83',
#   'Team': 'Utah(0-1)',
#   'AP Rank': '-',
#   'Past Rank': '67',
#   'Score Change': '-83',
#   'Breakdown': 'See Link'},
#  'Michigan': {'Rank': '76',
#   'Score': '-113',
#   'Team': 'Michigan(2-3)',
#   'AP Rank': '-',
#   'Past Rank': '86',
#   'Score Change': '+88',
#   'Breakdown': 'See Link'},
#  'Minnesota': {'Rank': '77',
#   'Score': '-117',
#   'Team': 'Minnesota(2-3)',
#   'AP Rank': '-',
#   'Past Rank': '97',
#   'Score Change': '+148',
#   'Breakdown': 'See Link'},
#  'Stanford': {'Rank': '78',
#   'Score': '-133',
#   'Team': 'Stanford(0-2)',
#   'AP Rank': '-',
#   'Past Rank': '84',
#   'Score Change': '+21',
#   'Breakdown': 'See Link'},
#  'Oregon State': {'Rank': '79',
#   'Score': '-154',
#   'Team': 'Oregon State(1-2)',
#   'AP Rank': '-',
#   'Past Rank': '93',
#   'Score Change': '+86',
#   'Breakdown': 'See Link'},
#  'Arizona': {'Rank': '80',
#   'Score': '-160',
#   'Team': 'Arizona(0-2)',
#   'AP Rank': '-',
#   'Past Rank': '79',
#   'Score Change': '-83',
#   'Breakdown': 'See Link'},
#  'Arkansas': {'Rank': '81',
#   'Score': '-160',
#   'Team': 'Arkansas(3-5)',
#   'AP Rank': '-',
#   'Past Rank': '77',
#   'Score Change': '-93',
#   'Breakdown': 'See Link'},
#  'Missouri': {'Rank': '82',
#   'Score': '-179',
#   'Team': 'Missouri(3-3)',
#   'AP Rank': '-',
#   'Past Rank': '87',
#   'Score Change': '+32',
#   'Breakdown': 'See Link'},
#  'Georgia State': {'Rank': '83',
#   'Score': '-184',
#   'Team': 'Georgia State(4-4)',
#   'AP Rank': '-',
#   'Past Rank': '62',
#   'Score Change': '-205',
#   'Breakdown': 'See Link'},
#  'Kentucky': {'Rank': '84',
#   'Score': '-199',
#   'Team': 'Kentucky(3-5)',
#   'AP Rank': '-',
#   'Past Rank': '92',
#   'Score Change': '+34',
#   'Breakdown': 'See Link'},
#  'Rutgers': {'Rank': '85',
#   'Score': '-207',
#   'Team': 'Rutgers(1-4)',
#   'AP Rank': '-',
#   'Past Rank': '89',
#   'Score Change': '+13',
#   'Breakdown': 'See Link'},
#  'Illinois': {'Rank': '86',
#   'Score': '-211',
#   'Team': 'Illinois(2-3)',
#   'AP Rank': '-',
#   'Past Rank': '99',
#   'Score Change': '+62',
#   'Breakdown': 'See Link'},
#  'Ole Miss': {'Rank': '87',
#   'Score': '-228',
#   'Team': 'Ole Miss(3-4)',
#   'AP Rank': '-',
#   'Past Rank': '94',
#   'Score Change': '+18',
#   'Breakdown': 'See Link'},
#  'Michigan State': {'Rank': '88',
#   'Score': '-239',
#   'Team': 'Michigan State(1-3)',
#   'AP Rank': '-',
#   'Past Rank': '98',
#   'Score Change': '+34',
#   'Breakdown': 'See Link'},
#  'Troy': {'Rank': '89',
#   'Score': '-247',
#   'Team': 'Troy(4-4)',
#   'AP Rank': '-',
#   'Past Rank': '54',
#   'Score Change': '-312',
#   'Breakdown': 'See Link'},
#  'Arkansas State': {'Rank': '90',
#   'Score': '-252',
#   'Team': 'Arkansas State(3-6)',
#   'AP Rank': '-',
#   'Past Rank': '61',
#   'Score Change': '-273',
#   'Breakdown': 'See Link'},
#  'UMass': {'Rank': '91',
#   'Score': '-257',
#   'Team': 'UMass(0-3)',
#   'AP Rank': '-',
#   'Past Rank': '81',
#   'Score Change': '-151',
#   'Breakdown': 'See Link'},
#  'Nebraska': {'Rank': '92',
#   'Score': '-267',
#   'Team': 'Nebraska(1-3)',
#   'AP Rank': '-',
#   'Past Rank': '78',
#   'Score Change': '-198',
#   'Breakdown': 'See Link'},
#  'Tennessee': {'Rank': '93',
#   'Score': '-281',
#   'Team': 'Tennessee(2-5)',
#   'AP Rank': '-',
#   'Past Rank': '95',
#   'Score Change': '-29',
#   'Breakdown': 'See Link'},
#  'Baylor': {'Rank': '94',
#   'Score': '-289',
#   'Team': 'Baylor(1-5)',
#   'AP Rank': '-',
#   'Past Rank': '108',
#   'Score Change': '+88',
#   'Breakdown': 'See Link'},
#  'LSU': {'Rank': '95',
#   'Score': '-289',
#   'Team': 'LSU(3-3)',
#   'AP Rank': '-',
#   'Past Rank': '112',
#   'Score Change': '+143',
#   'Breakdown': 'See Link'},
#  'Mississippi State': {'Rank': '96',
#   'Score': '-298',
#   'Team': 'Mississippi State(2-5)',
#   'AP Rank': '-',
#   'Past Rank': '103',
#   'Score Change': '+49',
#   'Breakdown': 'See Link'},
#  'Eastern Michigan': {'Rank': '97',
#   'Score': '-303',
#   'Team': 'Eastern Michigan(0-3)',
#   'AP Rank': '-',
#   'Past Rank': '88',
#   'Score Change': '-86',
#   'Breakdown': 'See Link'},
#  'Duke': {'Rank': '98',
#   'Score': '-314',
#   'Team': 'Duke(2-6)',
#   'AP Rank': '-',
#   'Past Rank': '104',
#   'Score Change': '+41',
#   'Breakdown': 'See Link'},
#  'Bowling Green': {'Rank': '99',
#   'Score': '-314',
#   'Team': 'Bowling Green(0-3)',
#   'AP Rank': '-',
#   'Past Rank': '101',
#   'Score Change': '-27',
#   'Breakdown': 'See Link'},
#  'Northern Illinois': {'Rank': '100',
#   'Score': '-318',
#   'Team': 'Northern Illinois(0-3)',
#   'AP Rank': '-',
#   'Past Rank': '85',
#   'Score Change': '-141',
#   'Breakdown': 'See Link'},
#  'California': {'Rank': '101',
#   'Score': '-322',
#   'Team': 'California(0-2)',
#   'AP Rank': '-',
#   'Past Rank': '68',
#   'Score Change': '-322',
#   'Breakdown': 'See Link'},
#  'Akron': {'Rank': '102',
#   'Score': '-335',
#   'Team': 'Akron(0-3)',
#   'AP Rank': '-',
#   'Past Rank': '96',
#   'Score Change': '-83',
#   'Breakdown': 'See Link'},
#  'UNLV': {'Rank': '103',
#   'Score': '-344',
#   'Team': 'UNLV(0-4)',
#   'AP Rank': '-',
#   'Past Rank': '102',
#   'Score Change': '-5',
#   'Breakdown': 'See Link'},
#  'Charlotte': {'Rank': '104',
#   'Score': '-348',
#   'Team': 'Charlotte(2-3)',
#   'AP Rank': '-',
#   'Past Rank': '111',
#   'Score Change': '+65',
#   'Breakdown': 'See Link'},
#  'New Mexico': {'Rank': '105',
#   'Score': '-349',
#   'Team': 'New Mexico(0-4)',
#   'AP Rank': '-',
#   'Past Rank': '91',
#   'Score Change': '-117',
#   'Breakdown': 'See Link'},
#  'Utah State': {'Rank': '106',
#   'Score': '-363',
#   'Team': 'Utah State(0-4)',
#   'AP Rank': '-',
#   'Past Rank': '107',
#   'Score Change': '+13',
#   'Breakdown': 'See Link'},
#  'Louisville': {'Rank': '107',
#   'Score': '-378',
#   'Team': 'Louisville(3-6)',
#   'AP Rank': '-',
#   'Past Rank': '106',
#   'Score Change': '-8',
#   'Breakdown': 'See Link'},
#  'Georgia Tech': {'Rank': '108',
#   'Score': '-402',
#   'Team': 'Georgia Tech(2-5)',
#   'AP Rank': '-',
#   'Past Rank': '109',
#   'Score Change': '-22',
#   'Breakdown': 'See Link'},
#  'Florida State': {'Rank': '109',
#   'Score': '-436',
#   'Team': 'Florida State(2-6)',
#   'AP Rank': '-',
#   'Past Rank': '116',
#   'Score Change': '+62',
#   'Breakdown': 'See Link'},
#  'South Carolina': {'Rank': '110',
#   'Score': '-492',
#   'Team': 'South Carolina(2-6)',
#   'AP Rank': '-',
#   'Past Rank': '114',
#   'Score Change': '-25',
#   'Breakdown': 'See Link'},
#  'Rice': {'Rank': '111',
#   'Score': '-507',
#   'Team': 'Rice(1-2)',
#   'AP Rank': '-',
#   'Past Rank': '100',
#   'Score Change': '-232',
#   'Breakdown': 'See Link'},
#  'North Texas': {'Rank': '112',
#   'Score': '-514',
#   'Team': 'North Texas(3-3)',
#   'AP Rank': '-',
#   'Past Rank': '122',
#   'Score Change': '+336',
#   'Breakdown': 'See Link'},
#  'Western Kentucky': {'Rank': '113',
#   'Score': '-520',
#   'Team': 'Western Kentucky(4-6)',
#   'AP Rank': '-',
#   'Past Rank': '117',
#   'Score Change': '+37',
#   'Breakdown': 'See Link'},
#  'South Alabama': {'Rank': '114',
#   'Score': '-531',
#   'Team': 'South Alabama(3-6)',
#   'AP Rank': '-',
#   'Past Rank': '90',
#   'Score Change': '-305',
#   'Breakdown': 'See Link'},
#  'Penn State': {'Rank': '115',
#   'Score': '-542',
#   'Team': 'Penn State(0-5)',
#   'AP Rank': '-',
#   'Past Rank': '110',
#   'Score Change': '-161',
#   'Breakdown': 'See Link'},
#  'East Carolina': {'Rank': '116',
#   'Score': '-557',
#   'Team': 'East Carolina(2-6)',
#   'AP Rank': '-',
#   'Past Rank': '113',
#   'Score Change': '-109',
#   'Breakdown': 'See Link'},
#  'Syracuse': {'Rank': '117',
#   'Score': '-591',
#   'Team': 'Syracuse(1-8)',
#   'AP Rank': '-',
#   'Past Rank': '115',
#   'Score Change': '-94',
#   'Breakdown': 'See Link'},
#  'UTEP': {'Rank': '118',
#   'Score': '-606',
#   'Team': 'UTEP(3-4)',
#   'AP Rank': '-',
#   'Past Rank': '119',
#   'Score Change': '+86',
#   'Breakdown': 'See Link'},
#  'Middle Tennessee': {'Rank': '119',
#   'Score': '-612',
#   'Team': 'Middle Tennessee(3-6)',
#   'AP Rank': '-',
#   'Past Rank': '124',
#   'Score Change': '+322',
#   'Breakdown': 'See Link'},
#  'Texas State': {'Rank': '120',
#   'Score': '-638',
#   'Team': 'Texas State(2-9)',
#   'AP Rank': '-',
#   'Past Rank': '118',
#   'Score Change': '+32',
#   'Breakdown': 'See Link'},
#  'Kansas': {'Rank': '121',
#   'Score': '-720',
#   'Team': 'Kansas(0-7)',
#   'AP Rank': '-',
#   'Past Rank': '123',
#   'Score Change': '+157',
#   'Breakdown': 'See Link'},
#  'Southern Mississippi': {'Rank': '122',
#   'Score': '-809',
#   'Team': 'Southern Mississippi(2-7)',
#   'AP Rank': '-',
#   'Past Rank': '121',
#   'Score Change': '-20',
#   'Breakdown': 'See Link'},
#  'Temple': {'Rank': '123',
#   'Score': '-899',
#   'Team': 'Temple(1-6)',
#   'AP Rank': '-',
#   'Past Rank': '105',
#   'Score Change': '-536',
#   'Breakdown': 'See Link'},
#  'South Florida': {'Rank': '124',
#   'Score': '-978',
#   'Team': 'South Florida(1-7)',
#   'AP Rank': '-',
#   'Past Rank': '120',
#   'Score Change': '-264',
#   'Breakdown': 'See Link'},
#  'Vanderbilt': {'Rank': '125',
#   'Score': '-1345',
#   'Team': 'Vanderbilt(0-7)',
#   'AP Rank': '-',
#   'Past Rank': '125',
#   'Score Change': '+154',
#   'Breakdown': 'See Link'},
#  'Louisiana Monroe': {'Rank': '126',
#   'Score': '-1942',
#   'Team': 'Louisiana Monroe(0-8)',
#   'AP Rank': '-',
#   'Past Rank': '126',
#   'Score Change': '-270',
#   'Breakdown': 'See Link'},
#  'Florida International': {'Rank': '127',
#   'Score': '-2896',
#   'Team': 'Florida International(0-5)',
#   'AP Rank': '-',
#   'Past Rank': '127',
#   'Score Change': '-180',
#   'Breakdown': 'See Link'},
#  'FCS Team': {'Rank': '128',
#   'Score': '-3252',
#   'Team': 'FCS Team(1-32)',
#   'AP Rank': '-',
#   'Past Rank': '128',
#   'Score Change': '-222',
#   'Breakdown': 'See Link'}}

# %%
start = time.time()
batch_start = time.time()

rankings = {}
scores = {}
for team in records:
    rankings[team] = 0
    scores[team] = [0]

team_count = len(rankings.keys())

rank_history = [] # used for checking if we have hit a repeating pattern based on ranks
past_averaged_history = '' # used to see if the patterns are broadly repeating
rank_history_set = set() 
score_history = [] # used for easier lookups of what team scores were in said repeating pattern
averaged_score_history = [] 
scores = {} # {teamname: listof scores (first value is sum, subsequent scores are per each game)
repeat_point = 0
pattern_found = False
# Repeat for 100000 interations, but it should hit a repeating steady state before then
for i in range(1000001):
    for team in records.keys():
        scores[team] = [0] # the first value is the total score
        games = records[team]
        for game in games:
            opponent = game[0]
            margin = game[1]
            multiplier = math.log(abs(margin))/math.log(MARGIN_LOG) + 1
            multiplier *= 1000 # just for nicer numbers
            game_score = 0
            if margin < 0:
                game_score -= L_SHARE * rankings[opponent] / team_count
                game_score -= I_SHARE / (team_count - rankings[opponent])
                if rankings[opponent] > rankings[team]:
                    game_score -= TRANSFER_RATIO * L_SHARE * (team_count - rankings[team]) / team_count
                    game_score -= TRANSFER_RATIO * I_SHARE / (1 + rankings[team])
            if margin > 0:
                game_score += L_SHARE * (team_count - rankings[opponent]) / team_count
                game_score += I_SHARE / (1 + rankings[opponent])
                if rankings[opponent] < rankings[team]:
                    game_score += TRANSFER_RATIO * L_SHARE * rankings[team] / team_count
                    game_score += TRANSFER_RATIO * I_SHARE / (team_count - rankings[team])
            scores[team] += [multiplier * game_score]
        if i == 0:
            scores[team][0] = sum(scores[team])
        elif i == 1:
            scores[team][0] = (sum(scores[team]) + score_history[-1][team][0]) / 2
        else:
            scores[team][0] = (sum(scores[team]) 
                               + (2 * score_history[-1][team][0] 
                                  - score_history[-2][team][0])) / 2
    # This is sorted, but adjusting so tied teams have the same (higher) rank
    new_rank_orders = sorted(scores, key=scores.__getitem__, reverse=True)
    #print(new_rank_orders)
    new_ranks = rankings
    new_ranks[new_rank_orders[0]] = 0
    past_rank = 0
    past_score = scores[new_rank_orders[0]][0]
    for rank, team in enumerate(new_rank_orders):
        if (abs(scores[team][0] - past_score) < 0.01):
            new_ranks[team] = past_rank
        else:
            new_ranks[team] = rank
        past_rank = new_ranks[team]
        past_score = scores[team][0]
    # stop if we are repeating ourselves, record this if we are not
    if False:
        repeat_point = rank_history.index(str(new_ranks))
        pattern_found = True
        break
    else:
        rank_history += [str(new_ranks)]
        rank_history_set.add(str(new_ranks))
        score_history += [scores.copy()]
        rankings = new_ranks
        
    # stop if we are *broadly* repeating ourselves
    if i%1000 == 0 and i != 0:
        print(i, 'Iterations Took: ' + str(round(time.time() - batch_start)))
        check_start = time.time()
        
        for team in records:
            score = [x[team] for x in score_history]
            scores[team] = list(map(mean, zip(*score)))
            scores[team][0] = sum(scores[team][1:]) 
        new_rank_orders = sorted(scores, key=scores.__getitem__, reverse=True)
        if str(new_rank_orders) == past_averaged_history:
            pattern_found = True
            break
        else:
            averaged_score_history += [scores.copy()]
            past_averaged_history = str(new_rank_orders)
        print(i, 'Check Took: ' + str(round(time.time() - check_start)))
        batch_start = time.time()
        
        
        
    if i>=1000:
        old_news = rank_history[0]
        del rank_history[0]
        del score_history[0]
            

print(i)
# Out:
# 1000 Iterations Took: 6
# 1000 Check Took: 4
# 2000 Iterations Took: 7
# 2000 Check Took: 5
# 3000 Iterations Took: 8
# 3000 Check Took: 5
# 4000 Iterations Took: 8
# 4000 Check Took: 5
# 5000 Iterations Took: 7
# 5000 Check Took: 5
# 6000 Iterations Took: 6
# 6000 Check Took: 6
# 7000 Iterations Took: 8
# 7000 Check Took: 4
# 8000 Iterations Took: 6
# 8000 Check Took: 4
# 9000 Iterations Took: 5
# 9000 Check Took: 2
# 10000 Iterations Took: 3
# 10000 Check Took: 4
# 11000 Iterations Took: 7
# 11000 Check Took: 4
# 12000 Iterations Took: 10
# 12000 Check Took: 4
# 13000 Iterations Took: 6
# 13000 Check Took: 5
# 14000 Iterations Took: 8
# 14000 Check Took: 4
# 15000 Iterations Took: 8
# 15000 Check Took: 5
# 16000 Iterations Took: 8
# 16000 Check Took: 5
# 17000 Iterations Took: 6
# 17000 Check Took: 4
# 18000 Iterations Took: 7
# 18000 Check Took: 5
# 19000 Iterations Took: 7
# 19000 Check Took: 5
# 20000 Iterations Took: 6
# 20000 Check Took: 4
# 21000 Iterations Took: 6
# 21000 Check Took: 4
# 22000 Iterations Took: 8
# 22000 Check Took: 3
# 966000 Iterations Took: 10
# 966000 Check Took: 7
# 967000 Iterations Took: 9
# 967000 Check Took: 8
# 968000 Iterations Took: 10
# 968000 Check Took: 7
# 969000 Iterations Took: 10
# 969000 Check Took: 7
# 970000 Iterations Took: 10
# 970000 Check Took: 6
# 971000 Iterations Took: 10
# 971000 Check Took: 7
# 972000 Iterations Took: 8
# 972000 Check Took: 7
# 973000 Iterations Took: 10
# 973000 Check Took: 7
# 974000 Iterations Took: 11
# 974000 Check Took: 7
# 975000 Iterations Took: 12
# 975000 Check Took: 7
# 976000 Iterations Took: 10
# 976000 Check Took: 7
# 977000 Iterations Took: 10
# 977000 Check Took: 5
# 978000 Iterations Took: 8
# 978000 Check Took: 6
# 979000 Iterations Took: 11
# 979000 Check Took: 7
# 980000 Iterations Took: 11
# 980000 Check Took: 8
# 981000 Iterations Took: 12
# 981000 Check Took: 8
# 982000 Iterations Took: 11
# 982000 Check Took: 8
# 983000 Iterations Took: 9
# 983000 Check Took: 8
# 984000 Iterations Took: 11
# 984000 Check Took: 7
# 985000 Iterations Took: 10
# 985000 Check Took: 4
# 986000 Iterations Took: 8
# 986000 Check Took: 8
# 987000 Iterations Took: 11
# 987000 Check Took: 7
# 988000 Iterations Took: 11
# 988000 Check Took: 8
# 989000 Iterations Took: 11
# 989000 Check Took: 6
# 990000 Iterations Took: 11
# 990000 Check Took: 8
# 991000 Iterations Took: 8
# 991000 Check Took: 4
# 992000 Iterations Took: 9
# 992000 Check Took: 8
# 993000 Iterations Took: 12
# 993000 Check Took: 8
# 994000 Iterations Took: 11
# 994000 Check Took: 8
# 995000 Iterations Took: 12
# 995000 Check Took: 7
# 996000 Iterations Took: 6
# 996000 Check Took: 4
# 997000 Iterations Took: 6
# 997000 Check Took: 4
# 998000 Iterations Took: 6
# 998000 Check Took: 4
# 999000 Iterations Took: 10
# 999000 Check Took: 8
# 1000000 Iterations Took: 10
# 1000000 Check Took: 8
# 1000000

# %%
# average across repeated cycled
for team in records:
    score = []
    if pattern_found: 
        for i in range(repeat_point, len(rank_history)):
            score += [score_history[i][team]]
    else:
        score = [x[team] for x in averaged_score_history]
    scores[team] = list(map(mean, zip(*score)))
    scores[team][0] = sum(scores[team][1:]) 
new_rank_orders = sorted(scores, key=scores.__getitem__, reverse=True)
output = ('My Goldfish Computer Poll!\n'
          + 'It only takes into account games played this season (as if it has the memory of a goldfish, thus the name), looking only at margin and quality of wins and losses individually:\n\n'
          + '|Rank|Score|Team|AP Rank|Past Rank|Score Change|Breakdown|\n'
          + '|-|-|-|-|-|-|-|\n')
for i, team in enumerate(new_rank_orders):
    W = len([x for x in records[team] if x[1] > 0])
    L = len([x for x in records[team] if x[1] < 0])
    explanation = ''
    for j in range(0, len(scores[team]) - 1):
        explanation += (str(round(scores[team][j + 1])) + ' from #'
                        + str(new_rank_orders.index(records[team][j][0]) + 1) + ' '
                        + str(records[team][j][0]) 
                        + '(' + str(records[team][j][1]) + '), ')
    explanation = 'See Link  '
        
    score_change = round(scores[team][0]) - int(last_week_table[team]['Score'])
    if score_change > 0:
        score_change_text = '+' + str(score_change)
    else:
        score_change_text = str(score_change)
        
    line = ('|' + str(i+1) + '|' 
            + str(round(scores[team][0])) + '|' 
            + team + '(' + str(W) + '-' + str(L) + ')' + '|' 
            + AP_Ranks[team] +'|'
            + last_week_table[team]['Rank'] + '|'
            + score_change_text + '|'
            + explanation[0:-2] + '\n')
    output += line
print(output)
with open('Output - '
        + str(YEAR) 
          + '-' 
          + str(WEEK) + '.md', 'w') as text_file:
    text_file.write(output)
# Out:
# My Goldfish Computer Poll!
# It only takes into account games played this season (as if it has the memory of a goldfish, thus the name), looking only at margin and quality of wins and losses individually:
#
# |Rank|Score|Team|AP Rank|Past Rank|Score Change|Breakdown|
# |-|-|-|-|-|-|-|
# |1|1814|Notre Dame(9-0)|2|6|+798|See Link
# |2|1524|Clemson(8-1)|4|5|+456|See Link
# |3|1336|BYU(9-0)|8|1|-48|See Link
# |4|1275|Cincinnati(8-0)|7|2|-47|See Link
# |5|1195|Alabama(8-0)|1|3|-82|See Link
# |6|1151|Coastal Carolina(9-0)|14|4|+59|See Link
# |7|1035|Miami(7-1)|9|8|+159|See Link
# |8|884|Louisiana(8-1)|20|9|+31|See Link
# |9|877|Marshall(7-0)|15|7|-1|See Link
# |10|693|Ohio State(4-0)|3|18|+204|See Link
# |11|640|Buffalo(4-0)|-|25|+269|See Link
# |12|637|Iowa State(7-2)|12|11|-16|See Link
# |13|605|Indiana(5-1)|10|29|+282|See Link
# |14|543|Boise State(4-1)|-|12|-18|See Link
# |15|530|Oklahoma State(6-2)|19|15|-7|See Link
# |16|522|Oklahoma(6-2)|13|13|-39|See Link
# |17|517|Florida(7-1)|6|14|-38|See Link
# |18|475|Texas A&M(6-1)|5|17|-40|See Link
# |19|475|Tulsa(5-1)|22|20|+22|See Link
# |20|445|Western Michigan(4-0)|-|22|+57|See Link
# |21|431|North Carolina(6-3)|-|28|+108|See Link
# |22|426|UCF(6-3)|-|26|+75|See Link
# |23|423|San José State(4-0)|-|16|-114|See Link
# |24|389|Colorado(3-0)|-|42|+196|See Link
# |25|387|Appalachian State(7-2)|-|30|+93|See Link
# |26|374|Georgia(6-2)|11|19|-86|See Link
# |27|366|Liberty(9-1)|25|34|+112|See Link
# |28|353|NC State(7-3)|-|33|+98|See Link
# |29|323|Florida Atlantic(5-1)|-|27|-3|See Link
# |30|318|Northwestern(5-1)|16|10|-405|See Link
# |31|318|Wake Forest(4-3)|-|37|+77|See Link
# |32|310|Washington(3-0)|23|41|+97|See Link
# |33|262|Pittsburgh(5-5)|-|43|+79|See Link
# |34|251|Texas(5-3)|-|31|-39|See Link
# |35|242|USC(3-0)|17|32|-33|See Link
# |36|239|Central Michigan(3-1)|-|47|+104|See Link
# |37|226|Houston(3-3)|-|39|+2|See Link
# |38|217|Virginia(4-4)|-|48|+86|See Link
# |39|209|Wisconsin(2-1)|18|35|-37|See Link
# |40|208|Iowa(4-2)|24|53|+135|See Link
# |41|204|Virginia Tech(4-5)|-|49|+76|See Link
# |42|199|Miami (OH)(2-1)|-|56|+141|See Link
# |98|-372|South Alabama(4-6)|-|114|+159|See Link
# |99|-376|Troy(4-5)|-|89|-129|See Link
# |100|-378|Duke(2-7)|-|98|-64|See Link
# |101|-378|Kentucky(3-6)|-|84|-179|See Link
# |102|-397|Eastern Michigan(0-4)|-|97|-94|See Link
# |103|-405|UMass(0-4)|-|91|-148|See Link
# |104|-415|Arkansas State(3-7)|-|90|-163|See Link
# |105|-421|Tennessee(2-5)|-|93|-140|See Link
# |106|-428|Utah State(1-4)|-|106|-65|See Link
# |107|-449|Akron(0-4)|-|102|-114|See Link
# |108|-455|Western Kentucky(4-6)|-|113|+65|See Link
# |109|-479|LSU(3-4)|-|95|-190|See Link
# |110|-514|Bowling Green(0-4)|-|99|-200|See Link
# |111|-537|Syracuse(1-9)|-|117|+54|See Link
# |112|-545|Mississippi State(2-6)|-|96|-247|See Link
# |113|-551|Rice(1-2)|-|111|-44|See Link
# |114|-579|UTEP(3-4)|-|118|+27|See Link
# |115|-588|North Texas(3-4)|-|112|-74|See Link
# |116|-621|UNLV(0-5)|-|103|-277|See Link
# |117|-675|Middle Tennessee(3-6)|-|119|-63|See Link
# |118|-686|Texas State(2-10)|-|120|-48|See Link
# |119|-690|South Carolina(2-7)|-|110|-198|See Link
# |120|-694|Temple(1-6)|-|123|+205|See Link
# |121|-697|New Mexico(0-5)|-|105|-348|See Link
# |122|-767|South Florida(1-8)|-|124|+211|See Link
# |123|-798|Southern Mississippi(2-7)|-|122|+11|See Link
# |124|-954|Kansas(0-8)|-|121|-234|See Link
# |125|-1778|Louisiana Monroe(0-9)|-|126|+164|See Link
# |126|-1991|Vanderbilt(0-8)|-|125|-646|See Link
# |127|-2770|Florida International(0-5)|-|127|+126|See Link
# |128|-3243|FCS Team(1-32)|-|128|+9|See Link

# %%
ranks = []
for i in range (5):
    ranks.append(sorted(scores, key=score_history[-i].__getitem__, reverse=True))
for i in range(len(ranks[0])):
    row = str(i) + ' '
    for j in range (5):
        row += ranks[j][i] + ' '
    print(row)
# Out:
# 0 Notre Dame Notre Dame Clemson Notre Dame Notre Dame
# 1 BYU Clemson Notre Dame Clemson Clemson
# 2 Clemson BYU BYU BYU BYU
# 3 Cincinnati Cincinnati Alabama Cincinnati Cincinnati
# 4 Alabama Alabama Cincinnati Alabama Alabama
# 5 Coastal Carolina Coastal Carolina Coastal Carolina Coastal Carolina Coastal Carolina
# 6 Miami Miami Miami Miami Miami
# 7 Marshall Louisiana Louisiana Louisiana Louisiana
# 8 Louisiana Marshall Marshall Marshall Marshall
# 9 Ohio State Ohio State Ohio State Ohio State Ohio State
# 10 Buffalo Buffalo Iowa State Iowa State Iowa State
# 11 Iowa State Iowa State Buffalo Buffalo Buffalo
# 12 Indiana Indiana Oklahoma State Florida Indiana
# 13 Florida Boise State Florida Indiana Oklahoma State
# 14 Oklahoma State Oklahoma Indiana Boise State Boise State
# 15 Boise State Florida Boise State Tulsa Oklahoma
# 16 Oklahoma Texas A&M Oklahoma Oklahoma Tulsa
# 17 Tulsa Oklahoma State Texas A&M Oklahoma State Texas A&M
# 18 Texas A&M Tulsa NC State Texas A&M Florida
