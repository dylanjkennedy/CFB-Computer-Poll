# %%
import math
import requests
import datetime
from statistics import mean
import time
import sys

YEAR = 2019
WEEK = 16
POST_WEEK = 2
LI_RATIO = .1
L_SHARE = LI_RATIO
I_SHARE = 1 - LI_RATIO
TRANSFER_RATIO = 1
MARGIN_LOG = 7

# %%
#prev = requests.get('https://api.collegefootballdata.com/games?year=' + str(YEAR - 1) + '&seasonType=regular')
#prev_post = requests.get('https://api.collegefootballdata.com/games?year=' + str(YEAR - 1) + '&seasonType=postseason')
reg = requests.get('https://api.collegefootballdata.com/games?year=' + str(YEAR) + '&seasonType=regular')
post = requests.get('https://api.collegefootballdata.com/games?year=' + str(YEAR) + '&seasonType=postseason')
records = {}
games = reg.json() + post.json() #+ prev.json() + prev_post.json()

# %%
for game in games:
        
    away_team = game['away_team']
    home_team = game['home_team']
    
    # With this dataset, no conference listed means they are an FCS team. 
    # I treat all FCS teams as the same, likely crappy team. 
    if not game['away_conference']:
        away_team = 'FCS Team'
    if not game['home_conference']:
        home_team = 'FCS Team'   
    
    if away_team not in records:
        records[away_team] = []
    if home_team not in records:
        records[home_team] = []
    
    if ((game['season_type'] != 'postseason'and game['week'] > WEEK) 
        or (game['season_type'] == 'postseason' and game['week'] > POST_WEEK)):
        continue
    
    # For invalid/unplayed games
    if game['away_points'] == None:
        continue
        
    margin = game['away_points'] - game['home_points']
    
    # Going to overtime counts as a one point win
    if len(game['away_line_scores']) > 4:
        margin = margin / abs(margin)
    records[away_team].append((home_team, margin))
    records[home_team].append((away_team, -margin))

# %%
records["BYU"]
# Out:
# [('Utah', -18),
#  ('Tennessee', 1.0),
#  ('USC', 1.0),
#  ('Washington', -26),
#  ('Toledo', -7),
#  ('South Florida', -4),
#  ('Boise State', 3),
#  ('Utah State', 28),
#  ('Liberty', 7),
#  ('FCS Team', 32),
#  ('UMass', 32),
#  ('San Diego State', -10),
#  ("Hawai'i", -4)]

# %%
start = time.time()

rankings = {}
scores = {}
for team in records:
    rankings[team] = 0
    scores[team] = [0]

team_count = len(rankings.keys())

rank_history = [] # used for checking if we have hit a repeating pattern based on ranks
rank_history_set = set() 
score_history = [] # used for easier lookups of what team scores were in said repeating pattern
scores = {} # {teamname: listof scores (first value is sum, subsequent scores are per each game)
repeat_point = 0
# Repeat for 100000 interations, but it should hit a repeating steady state before then
for i in range(1000000):
    for team in records.keys():
        scores[team] = [0] # the first value is the total score
        games = records[team]
        for game in games:
            opponent = game[0]
            margin = game[1]
            multiplier = math.log(abs(margin))/math.log(MARGIN_LOG) + 1
            multiplier *= 1000 # just for nicer numbers
            game_score = 0
            if margin < 0:
                game_score -= L_SHARE * rankings[opponent] / team_count
                game_score -= I_SHARE / (team_count - rankings[opponent])
                if rankings[opponent] > rankings[team]:
                    game_score -= TRANSFER_RATIO * L_SHARE * (team_count - rankings[team]) / team_count
                    game_score -= TRANSFER_RATIO * I_SHARE / (1 + rankings[team])
            if margin > 0:
                game_score += L_SHARE * (team_count - rankings[opponent]) / team_count
                game_score += I_SHARE / (1 + rankings[opponent])
                if rankings[opponent] < rankings[team]:
                    game_score += TRANSFER_RATIO * L_SHARE * rankings[team] / team_count
                    game_score += TRANSFER_RATIO * I_SHARE / (team_count - rankings[team])
            scores[team] += [multiplier * game_score]
        if i == 0:
            scores[team][0] = sum(scores[team])
        elif i == 1:
            scores[team][0] = (sum(scores[team]) + score_history[-1][team][0]) / 2
        else:
            scores[team][0] = (sum(scores[team]) 
                               + (2 * score_history[-1][team][0] 
                                  - score_history[-2][team][0])) / 2
    # This is sorted, but adjusting so tied teams have the same (higher) rank
    new_rank_orders = sorted(scores, key=scores.__getitem__, reverse=True)
    #print(new_rank_orders)
    new_ranks = rankings
    new_ranks[new_rank_orders[0]] = 0
    past_rank = 0
    past_score = scores[new_rank_orders[0]][0]
    for rank, team in enumerate(new_rank_orders):
        if (abs(scores[team][0] - past_score) < 0.01):
            new_ranks[team] = past_rank
        else:
            new_ranks[team] = rank
        past_rank = new_ranks[team]
        past_score = scores[team][0]
    # stop if we are repeating ourselves, record this if we are not
    # print(new_ranks['Duke'])
    if str(new_ranks) in rank_history_set:
        repeat_point = rank_history.index(str(new_ranks))
        break
    else:
        rank_history += [str(new_ranks)]
        rank_history_set.add(str(new_ranks))
        score_history += [scores.copy()]
        rankings = new_ranks
    if i%10000 == 0:
        print(i)
    if i>10000:
        old_news = rank_history[0]
        rank_history_set.remove(old_news)
        del rank_history[0]
        del score_history[0]
            

print(i)
# average across repeated cycled
for team in records:
    score = []
    for i in range(max(repeat_point,1), len(rank_history)):
        score += [score_history[i][team]]
    scores[team] = list(map(mean, zip(*score)))
    
    scores[team][0] = sum(scores[team][1:]) 
new_rank_orders = sorted(scores, key=scores.__getitem__, reverse=True)
output = ('My Computer Poll!\n'
          + 'It only takes into account games played this season, looking at margin and quality of wins and losses individually:\n\n'
          + '|Rank|Score|Team|Breakdown|\n'
          + '|-|-|-|-|\n')
for i, team in enumerate(new_rank_orders):
    W = len([x for x in records[team] if x[1] > 0])
    L = len([x for x in records[team] if x[1] < 0])
    explanation = ''
    for j in range(0, len(scores[team]) - 1):
        explanation += (str(round(scores[team][j + 1])) + ' from #'
                        + str(new_rank_orders.index(records[team][j][0]) + 1) + ' '
                        + str(records[team][j][0]) 
                        + '(' + str(records[team][j][1]) + '), ')
    line = ('|' + str(i+1) + '|' 
            + str(round(scores[team][0])) + '|' 
            + team + '(' + str(W) + '-' + str(L) + ')' + '|' 
            + explanation[0:-2] + '\n')
    output += line
print('Completed in ' + str(time.time() - start) + ' seconds')
print(output)
with open('Output - '
        + str(YEAR) 
          + '-' 
          + str(WEEK) + '.md', 'w') as text_file:
    text_file.write(output)
# Out:
# 0

# %%
ranks = []
for i in range (10):
    ranks.append(sorted(scores, key=score_history[-i].__getitem__, reverse=True))
for i in range(len(ranks[0])):
    row = str(i) + ' '
    for j in range (10):
        row += ranks[j][i] + ' '
    print(row)
# Out:
# 0 Clemson Clemson Clemson Clemson Clemson Clemson Clemson Clemson Clemson Clemson
# 1 Coastal Carolina Coastal Carolina Coastal Carolina Coastal Carolina Coastal Carolina Coastal Carolina Coastal Carolina Cincinnati Coastal Carolina Coastal Carolina
# 2 Cincinnati Cincinnati Cincinnati Cincinnati Cincinnati Cincinnati Cincinnati Coastal Carolina Cincinnati Cincinnati
# 3 Alabama Alabama Alabama Alabama Alabama Alabama Alabama BYU Alabama Alabama
# 4 BYU BYU BYU BYU BYU BYU BYU Alabama BYU BYU
# 5 Louisiana Louisiana Louisiana Louisiana Louisiana Louisiana Louisiana Louisiana Louisiana Louisiana
# 6 Marshall Marshall Marshall Marshall Marshall Marshall Marshall Marshall Marshall Marshall
# 7 Oklahoma State Oklahoma State Oklahoma State Oklahoma State Miami Miami Oklahoma State Oklahoma State Iowa State Miami
# 8 Miami Miami Miami Miami Iowa State Oklahoma State Miami Miami Miami Oklahoma State
# 9 Iowa State Iowa State Iowa State Iowa State Oklahoma State Iowa State Iowa State Notre Dame Oklahoma State Iowa State
# 10 Notre Dame Notre Dame Notre Dame Notre Dame Notre Dame Notre Dame Notre Dame Iowa State Notre Dame Notre Dame
# 11 SMU SMU Wake Forest NC State SMU Wake Forest NC State SMU Wake Forest NC State
# 12 Wake Forest Wake Forest SMU SMU Oklahoma SMU SMU Wake Forest SMU SMU
# 13 Georgia Oklahoma Oklahoma Memphis Wake Forest Oklahoma Appalachian State Oklahoma Oklahoma Memphis
# 14 Appalachian State Virginia Tech North Carolina Kansas State UCF North Carolina Kansas State Virginia Tech Memphis Kansas State
# 15 Virginia Tech Appalachian State Memphis Tulsa Virginia Tech Appalachian State Memphis Appalachian State North Carolina Tulsa
# 16 Memphis Georgia Appalachian State Appalachian State Appalachian State Memphis Virginia Tech Georgia Appalachian State Appalachian State
# 17 Tulsa Memphis Tulsa Virginia Tech Georgia Georgia Georgia Memphis Tulsa Virginia Tech
# 18 Oklahoma UCF Georgia Georgia Memphis Tulsa Oklahoma UCF Georgia Georgia
# 19 Texas A&M Tulsa Texas A&M Oklahoma Tulsa UCF Wake Forest Tulsa Texas A&M Oklahoma
# 20 UCF Texas A&M Indiana Wake Forest Texas A&M Texas A&M Tulsa Texas A&M Indiana Wake Forest
# 21 North Carolina North Carolina Virginia Tech Texas A&M Indiana Indiana Texas A&M North Carolina Virginia Tech Texas A&M
# 22 Indiana Indiana Ohio State Indiana North Carolina Ohio State Indiana Indiana Ohio State Indiana
# 23 Ohio State Ohio State Boise State Ohio State Ohio State Texas Ohio State Ohio State Boise State Ohio State
# 24 NC State Arkansas State San José State Boise State Boise State Boise State Boise State Arkansas State San José State Texas
# 25 San José State Boise State Texas San José State Arkansas State Virginia Tech North Carolina Boise State Texas Boise State
# 26 Boise State San José State San Diego State Texas San José State San José State San José State San José State San Diego State San José State
# 27 Texas Texas Army San Diego State Texas San Diego State UCF Texas Kansas State San Diego State
# 28 San Diego State San Diego State Kansas State North Carolina NC State Army Texas San Diego State Army North Carolina
# 29 Army NC State Nevada Army San Diego State Nevada San Diego State NC State Nevada Army
# 30 Kansas State Army Liberty Nevada Army Kansas State Army Army Liberty Nevada
# 31 Arkansas State West Virginia UCF Liberty West Virginia Liberty Nevada West Virginia UCF Troy
# 32 Nevada Nevada Wyoming Troy Nevada Wyoming Troy Nevada Wyoming Liberty
# 33 Liberty Liberty Northwestern Northwestern Liberty Northwestern Liberty Liberty Northwestern Northwestern
# 34 Northwestern Wyoming Georgia Southern Wyoming Wyoming Troy Northwestern Wyoming West Virginia Wyoming
# 35 Wyoming Northwestern West Virginia Georgia Southern Northwestern Georgia Southern Wyoming Northwestern Georgia Southern Georgia Southern
# 36 Georgia Southern Georgia Southern Troy Florida Georgia Southern West Virginia Georgia Southern Georgia Southern Troy Florida
# 37 West Virginia TCU Florida UCF Florida Florida Florida TCU Florida UCF
# 38 Florida Purdue Virginia Purdue Purdue Virginia Purdue Purdue Virginia Purdue
# 39 Boston College Florida Purdue Florida Atlantic TCU Purdue Florida Atlantic Florida Purdue Florida Atlantic
# 40 Purdue Florida Atlantic Arkansas State Boston College Boston College Arkansas State Boston College Florida Atlantic Arkansas State Boston College
# 41 Troy Boston College Florida Atlantic Georgia State Florida Atlantic Boston College West Virginia Boston College Florida Atlantic Georgia State
# 42 Florida Atlantic Troy Boston College West Virginia Troy Florida Atlantic Georgia State Troy Boston College West Virginia
# 43 Wisconsin Wisconsin Wisconsin Virginia Wisconsin Wisconsin Wisconsin Wisconsin Wisconsin Wisconsin
# 44 Virginia Texas Tech TCU Wisconsin Texas Tech NC State Virginia Texas Tech TCU Virginia
# 45 Texas Tech Virginia NC State Houston Virginia TCU TCU Virginia NC State Houston
# 46 TCU Georgia State Houston TCU Georgia State Rutgers Rutgers Georgia State Houston TCU
# 47 Georgia State Rutgers Rutgers Rutgers Houston Georgia State Arkansas State Rutgers Georgia State Rutgers
# 48 Rutgers Houston Georgia State Arkansas State Rutgers Houston Houston Houston Rutgers Arkansas State
# 49 Hawai'i Kansas State Texas Tech UAB Kansas State Texas Tech Hawai'i Kansas State Texas Tech Hawai'i
# 50 Houston Hawai'i Hawai'i Hawai'i UAB Hawai'i Texas Tech UAB UAB UAB
# 51 UAB UAB UAB Texas Tech Hawai'i UAB UAB Hawai'i Hawai'i Texas Tech
# 52 Louisiana Tech Louisiana Tech Louisiana Tech Western Michigan Western Michigan Louisiana Tech Louisiana Tech Western Michigan Western Michigan Louisiana Tech
# 53 Western Michigan Western Michigan Western Michigan Akron Akron Western Michigan Western Michigan Akron Akron Western Michigan
# 54 Akron Akron Akron Eastern Michigan Eastern Michigan Akron Akron Eastern Michigan Eastern Michigan Akron
# 55 Eastern Michigan Eastern Michigan Eastern Michigan Kent State Kent State Eastern Michigan Eastern Michigan Kent State Kent State Eastern Michigan
# 56 Kent State Kent State Kent State Ohio Ohio Kent State Kent State Ohio Ohio Kent State
# 57 Ohio Ohio Ohio Central Michigan Central Michigan Ohio Ohio Central Michigan Central Michigan Ohio
# 58 Central Michigan Central Michigan Central Michigan Ball State Ball State Central Michigan Central Michigan Ball State Ball State Central Michigan
# 59 Ball State Ball State Ball State Miami (OH) Miami (OH) Ball State Ball State Miami (OH) Miami (OH) Ball State
# 60 Miami (OH) Miami (OH) Miami (OH) Buffalo Buffalo Miami (OH) Miami (OH) Buffalo Buffalo Miami (OH)
# 61 Buffalo Buffalo Buffalo Northern Illinois Northern Illinois Buffalo Buffalo Northern Illinois Northern Illinois Buffalo
# 62 Northern Illinois Northern Illinois Northern Illinois Bowling Green Bowling Green Northern Illinois Northern Illinois Bowling Green Bowling Green Northern Illinois
# 63 Bowling Green Bowling Green Bowling Green Toledo Toledo Bowling Green Bowling Green Toledo Toledo Bowling Green
# 64 Toledo Toledo Toledo Arizona State Arizona State Toledo Toledo Arizona State Arizona State Toledo
# 65 Arizona State Arizona State Arizona State USC USC Arizona State Arizona State USC USC Arizona State
# 66 USC USC USC Arizona Arizona USC USC Arizona Arizona USC
# 67 Arizona Arizona Arizona Utah Utah Arizona Arizona Utah Utah Arizona
# 68 Utah Utah Utah UCLA UCLA Utah Utah UCLA UCLA Utah
# 69 UCLA UCLA UCLA Colorado Colorado UCLA UCLA Colorado Colorado UCLA
# 70 Colorado Colorado Colorado Stanford Stanford Colorado Colorado Stanford Stanford Colorado
# 71 Stanford Stanford Stanford Oregon Oregon Stanford Stanford Oregon Oregon Stanford
# 72 Oregon Oregon Oregon Washington State Washington State Oregon Oregon Washington State Washington State Oregon
# 73 Washington State Washington State Washington State Oregon State Oregon State Washington State Washington State Oregon State Oregon State Washington State
# 74 Oregon State Oregon State Oregon State Washington Washington Oregon State Oregon State Washington Washington Oregon State
# 75 Washington Washington Washington California California Washington Washington California California Washington
# 76 California California California Louisiana Tech Louisiana Tech California California Louisiana Tech Pittsburgh California
# 77 Pittsburgh Pittsburgh Pittsburgh Pittsburgh Pittsburgh Pittsburgh Pittsburgh Pittsburgh Louisiana Tech Pittsburgh
# 78 Michigan State Michigan State Michigan State Michigan State Michigan State Michigan State Michigan State Fresno State Michigan State Michigan State
# 79 Fresno State Fresno State Fresno State Fresno State Fresno State Fresno State Fresno State Michigan State Fresno State Fresno State
# 80 Air Force Air Force Air Force Air Force Air Force Air Force Air Force Air Force Air Force Air Force
# 81 Michigan Michigan Michigan Michigan Michigan Michigan Michigan Michigan Michigan Michigan
# 82 New Mexico New Mexico New Mexico New Mexico New Mexico New Mexico New Mexico New Mexico New Mexico New Mexico
# 83 Nebraska Nebraska Nebraska Nebraska Nebraska Nebraska Nebraska Nebraska Nebraska Nebraska
# 84 Maryland Maryland Maryland Maryland Maryland Maryland Maryland Maryland Maryland Maryland
# 85 Penn State Penn State Penn State Penn State Penn State Penn State Penn State Penn State Penn State Penn State
# 86 Iowa UT San Antonio Iowa UT San Antonio UT San Antonio Iowa Iowa UT San Antonio UT San Antonio UT San Antonio
# 87 UMass Iowa UMass Iowa Iowa UT San Antonio UMass Iowa Iowa Iowa
# 88 UT San Antonio UMass UT San Antonio UMass UMass UMass UT San Antonio UMass UMass UMass
# 89 Duke Auburn Louisville Georgia Tech Auburn Auburn Georgia Tech Auburn Louisville Georgia Tech
# 90 Baylor Utah State Auburn Tennessee Baylor Louisville Tennessee Utah State Auburn Tennessee
# 91 Arkansas Baylor Baylor Baylor Utah State Baylor Baylor Baylor Baylor Baylor
# 92 Utah State UNLV Utah State Utah State UNLV Utah State Utah State UNLV Utah State Utah State
# 93 UNLV Arkansas UNLV Arkansas Arkansas Kentucky Arkansas Arkansas UNLV Arkansas
# 94 Auburn Missouri Kentucky UNLV Florida State UNLV UNLV Missouri Kentucky UNLV
# 95 Louisville Florida State Arkansas Auburn Missouri Arkansas Auburn Florida State Arkansas Auburn
# 96 Colorado State Colorado State Colorado State Colorado State Colorado State Colorado State Colorado State Colorado State Colorado State Colorado State
# 97 Illinois Illinois Illinois Illinois Illinois Illinois Illinois Illinois Illinois Illinois
# 98 Tennessee Navy Navy Florida State Navy Navy Florida State Navy Navy Florida State
# 99 Florida State Duke Duke Tulane Duke Duke Duke Duke Duke Tulane
# 100 Navy Louisville Tennessee Duke Louisville Georgia Tech Rice Louisville Tennessee Duke
# 101 South Carolina Rice Rice Rice Rice Tennessee Missouri Rice Rice Rice
# 102 Kentucky Syracuse Georgia Tech Louisville Tulane Rice Tulane Kentucky Georgia Tech Louisville
# 103 Rice Kentucky Florida State Missouri Kentucky Tulane Louisville Syracuse Florida State Missouri
# 104 Missouri Tulane Tulane Navy Syracuse Florida State Navy Tulane Tulane Navy
# 105 Tulane Tennessee Minnesota Minnesota Georgia Tech Minnesota Minnesota Tennessee Minnesota Minnesota
# 106 Minnesota Minnesota South Alabama South Alabama Tennessee Missouri South Alabama Minnesota South Alabama South Alabama
# 107 South Alabama South Alabama Missouri Charlotte Minnesota South Alabama Charlotte South Alabama Missouri Charlotte
# 108 Georgia Tech South Carolina LSU Ole Miss South Alabama LSU South Carolina South Carolina LSU Ole Miss
# 109 Mississippi State Georgia Tech Charlotte South Carolina South Carolina Charlotte Ole Miss Georgia Tech Charlotte South Carolina
# 110 Ole Miss Charlotte Syracuse East Carolina Charlotte Syracuse East Carolina Charlotte Syracuse East Carolina
# 111 Charlotte Ole Miss South Carolina Syracuse East Carolina South Carolina Syracuse Ole Miss South Carolina Syracuse
# 112 Syracuse East Carolina East Carolina Mississippi State Ole Miss East Carolina Mississippi State East Carolina East Carolina Mississippi State
# 113 East Carolina Mississippi State Ole Miss UTEP Mississippi State Ole Miss UTEP Mississippi State Ole Miss UTEP
# 114 UTEP UTEP UTEP LSU UTEP UTEP LSU UTEP UTEP LSU
# 115 LSU Western Kentucky Western Kentucky Kentucky Western Kentucky Western Kentucky Kentucky Western Kentucky Western Kentucky Kentucky
# 116 Western Kentucky Temple Temple Western Kentucky Temple Temple Western Kentucky Temple Temple Western Kentucky
# 117 Temple LSU Mississippi State Temple LSU Mississippi State Temple LSU Mississippi State Temple
# 118 Texas State Kansas Kansas North Texas Kansas Kansas North Texas Kansas Kansas North Texas
# 119 Kansas Southern Mississippi Texas State Kansas Southern Mississippi Texas State Kansas Southern Mississippi Texas State Kansas
# 120 South Florida Texas State North Texas Texas State Texas State North Texas Texas State Texas State North Texas Texas State
# 121 Middle Tennessee South Florida South Florida South Florida South Florida South Florida South Florida South Florida South Florida South Florida
# 122 Southern Mississippi Middle Tennessee Southern Mississippi Southern Mississippi Middle Tennessee Southern Mississippi Southern Mississippi Middle Tennessee Southern Mississippi Southern Mississippi
# 123 North Texas North Texas Middle Tennessee Middle Tennessee North Texas Middle Tennessee Middle Tennessee North Texas Middle Tennessee Middle Tennessee
# 124 Vanderbilt Vanderbilt Vanderbilt Vanderbilt Vanderbilt Vanderbilt Vanderbilt Vanderbilt Vanderbilt Vanderbilt
# 125 Louisiana Monroe Louisiana Monroe Louisiana Monroe Louisiana Monroe Louisiana Monroe Louisiana Monroe Louisiana Monroe Louisiana Monroe Louisiana Monroe Louisiana Monroe
# 126 Florida International Florida International FCS Team Florida International Florida International FCS Team Florida International Florida International FCS Team Florida International
# 127 FCS Team FCS Team Florida International FCS Team FCS Team Florida International FCS Team FCS Team Florida International FCS Team
